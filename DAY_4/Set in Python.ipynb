# %% [markdown]
# # Sets
#
# Sets are a built-in data type in python used to store collections of unique items. They are unordered, meaning that the elements do not follow a specific order, and they do not allow duplicate elements. Sets are useful for intersection, difference, and symmetric difference.

# %%
## create a set using {} breaket.

my_set ={1,2,3,4,5}
print(my_set)
print(type(my_set))
# Out:
# {1, 2, 3, 4, 5}
# <class 'set'>

# %%
my_empty_set = set()
print(type(my_empty_set))
# Out:
# <class 'set'>

# %%
## Basics sets operation
## adding and removing elements
my_set = {1,2,3,4,5}
my_set.add(6)
print(my_set)
my_set.add(7)
print(my_set)
# Out:
# {1, 2, 3, 4, 5, 6}
# {1, 2, 3, 4, 5, 6, 7}

# %%
## pop method 
removed_element = my_set.pop()
print(removed_element)
print(my_set)
# Out:
# 1
# {2, 3, 4, 5, 6, 7}

# %%
## clear all this elements

my_set.clear()
print(my_set)
# Out:
# set()

# %%
## mathematical operation 

set1={1,2,3,4,5,6}
set2={4,5,6,7,8,9}

## union 
union_set = set1.union(set2)
print(union_set)

##intersection 
intersection_set = set1.intersection(set2)
print(intersection_set)


set1.intersection_update(set2)
print(set1)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}
# {4, 5, 6}
# {4, 5, 6}

# %%
## counting unique word in text 

text = " to day i learn python sets "
words=text.split()

## convert list of words to set to get unique words

unique_words = set(words)
print(unique_words)
print(len(unique_words))
# Out:
# {'sets', 'day', 'learn', 'python', 'i', 'to'}
# 6
