# %% [markdown]
# ## Tuple
#
# 1. Tuple is an data structure
# 2.A tuple is a collection data type that is:
#    * Ordered (items have a fixed position)
#    * Immutable (you cannot change it after creation)
#    * Written using parentheses ()
#
#
# Outline:-
# 1. Introduction to Tuple
# 2. Creating Tuples
# 3. Accessing Tuple Elements
# 4. Tuple Operations
# 5. immutable Nature of Tuple
# 6. Tuple Method
# 7. Packing and Unpacking Tuple
# 8. Nested Tuples
# 9. Practical Examples and Common Errors

# %% [markdown]
# ## Introduction to Tuples
#
# Tuples are ordered collection of items that are immutable . They are similar to list, but their immutability makes them different.

# %%
# Creating a tuple
empty_tuple = ()
print(empty_tuple)
print(type(empty_tuple))
# Out:
# ()
# <class 'tuple'>

# %%
mixed_tuple= (1,"Hello Nisha",3.5,True)
print(mixed_tuple)
print(type(mixed_tuple))
# Out:
# (1, 'Hello Nisha', 3.5, True)
# <class 'tuple'>

# %%
## Tuple Operation

number = (1,2,3,4)
concatenation_tuple = number + mixed_tuple
print(concatenation_tuple)
# Out:
# (1, 2, 3, 4, 1, 'Hello Nisha', 3.5, True)

# %%
mixed_tuple * 3
# Out:
# (1,
#  'Hello Nisha',
#  3.5,
#  True,
#  1,
#  'Hello Nisha',
#  3.5,
#  True,
#  1,
#  'Hello Nisha',
#  3.5,
#  True)

# %%
## Immutable Nature of Tuples
## Tuples are immutable, meaning their elements cannot be changed once assigned
