# %% [markdown]
# # Real-world Examples Using List in Python
#
# List are one of te most commonly used data structures in python, thanks to their versatility and ease of use. Here are several practical examplea that illustrate use in real_world secenario.
